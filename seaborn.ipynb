# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'D:\Data science\Data sample\sale and profit.csv',index_col=0)
df1=pd.read_csv(r'D:\Data science\Data sample\Patient details.csv')
df2=pd.read_csv(r'D:\Data science\Data sample\Sindh.csv')
df2.drop('datetime', axis=1)
df.head()
# Out:
#               Average Daily Customers
# Store Number
# 1.0                             120.0  \
# 2.0                             144.0
# 3.0                             394.0
# 4.0                             122.0
# 5.0                             132.0
#
#               Average Daily Splashtastic Sales (Units)
# Store Number
# 1.0                                                6.0  \
# 2.0                                               18.0
# 3.0                                               13.0
# 4.0                                               17.0
# 5.0                                                3.0
#
#               Average Daily Splashtastic Sales (Dollars)
# Store Number
# 1.0                                                25.02  \
# 2.0                                                75.06
# 3.0                                                54.21
# 4.0                                                70.89
# 5.0                                                12.51
#
# ...

# %%
sns.scatterplot(x='Average Daily Customers', y='Average Daily Splashtastic Sales (Units)', data=df, hue='Age', palette='dark')
# Out:
# <Axes: xlabel='Average Daily Customers', ylabel='Average Daily Splashtastic Sales (Units)'>

# %%
sns.histplot(df['Average Daily Customers'], kde=True,bins=15,color='skyblue')
# Out:
# <Axes: xlabel='Average Daily Customers', ylabel='Count'>

# %%
sns.displot(df['Average Daily Splashtastic Sales (Units)'], kde=True, bins=15, color='orange')

# %%
sns.barplot(x='Age',y='Gender',data=df1)
# Out:
# <Axes: xlabel='Age', ylabel='Gender'>

# %%
yp=np.arange(len(df1['Gender'].head(20)))

# %%
sns.boxplot(x=df1['Age'].head(20),y=yp,data=df1,hue='City',)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.stripplot(x='Age',y='Marital Status',data=df1, hue='City')
# Out:
# <Axes: xlabel='Age', ylabel='Marital Status'>

# %%
sns.jointplot(x='Average Daily Customers',y='Average Daily Splashtastic Sales (Dollars)',data=df,kind='hex',cmap='YlGnBu')#kind="reg" to add a line in sequense  kind='kde' to add kde line

# %%
sns.pairplot(df.select_dtypes(['number']),hue='Age')
plt.figure(figsize=(20,6))

# %%
sns.heatmap(df.corr(),annot=True, cmap='icefire') #cmap= 'icefire', 'YlGnBu', 'coolwarm'
# Out:
# <Axes: >
